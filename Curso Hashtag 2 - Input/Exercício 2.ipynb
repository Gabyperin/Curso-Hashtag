# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = int(input("Digite um numero inteiro: "))
print(f'O numero informado foi {numero}')
# Out:
# O numero informado foi 67

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero = int(input("Digite um numero inteiro: "))
numero2 = float(input("Digite um numero quebrado: "))
print(f'A soma dos dois numeros é: {numero + numero2}')
# Out:
# A soma dos dois numeros é: 121.0

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nome = str(input("Informe o nome do aluno:"))
nota1 = float(input('Informe a 1ª nota: '))
nota2 = float(input('Informe a 2ª nota: '))
nota3 = float(input('Informe a 3ª nota: '))
nota4 = float(input('Informe a 4ª nota: '))

media = (nota1 + nota2 + nota3 + nota4) / 4

print(f'A média final do(a) {nome} é: {media}')
# Out:
# A média final do aluno é 20.75

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
metros = float(input("Qual o comprimento em metros (m) "))

centimetro = metros * 100

print(f'O comprimento de metros para centimetros é de {centimetro}')
# Out:
# O comprimento de metros para centimetros é de 790.0

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura_da_sala = int(input("Informe a largura da sala: "))
comprimento_da_sala = int(input("Informe o comprimento da sala: "))

area_da_sala = largura_da_sala * comprimento_da_sala
print(f'A área da sala é de {area_da_sala} m²')
# Out:
# A área da sala é de 45

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
ganha_por_hora = int(input("Quanto você ganha por hora?: "))
horas_trabalhadas = int(input("Informe as horas trabalhadas: "))

total_salario = ganha_por_hora * horas_trabalhadas
print(f'O seu salário no final do mês será de R$ {total_salario} reais')
# Out:
# O seu salário no final do mês será de R$ 2100

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
temp_fahrenheit = int(input("Digite a temperatura em graus Fahrenheit: "))
temp_celsius = (5/9) * (temp_fahrenheit - 32)
print(f"A temperatura em graus Celsius é: {temp_celsius:.1f} °C")
# Out:
# A temperatura em graus Celsius é: 13.8 °C

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
temperatura_celsius = float(input("Digite a temperatura em graus Celsius"))
temperatura_fahrenheit = 9/5 * temperatura_celsius + 32
print(f"A temperatura em graus Fahrenheit é: {temperatura_fahrenheit:.1f} °F")
# Out:
# A temperatura em graus Fahrenheit é: 90.5 °F

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
altura = float(input("Digite a altura da pessoa em metros: "))
peso_ideal = 72.7 * altura - 58
print(f"O peso ideal para a altura {altura} cm é: {peso_ideal} kg")
# Out:
# O peso ideal para a altura 1.68 cm é: 64.136 kg

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
sexo = str(input("Você é homem ou mulher?: "))

if sexo == "homem" or sexo == "Homem":
    alturaH = float(input("Qual é a sua altura?:"))
    peso_idealH = 72.7 * alturaH - 58
    print(f"O peso ideal para a altura {alturaH} cm é: {peso_idealH} kg")

if sexo == "mulher" or "Mulher":
    alturaM = float(input("Qual é a sua altura?:"))
    peso_idealM = 62.1 * alturaM - 44.7
    print(f"O peso ideal para a altura {alturaM} é: {peso_idealM} kg")
# Out:
# O peso ideal para a altura 1.68 é: 59.628 kg

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
valor_por_hora1 = int(input("Digite o valor ganho por hora: "))
horas_trabalhadas = int(input("Digite o número de horas trabalhadas no mês: "))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
salario_bruto = valor_por_hora1 * horas_trabalhadas

print(f'O salário bruto no mês é: R$ {salario_bruto}')
# Out:
# O salário bruto no mês é: R$ 16000

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
desconto_ir = 0.11 * salario_bruto
print(f"O desconto do Imposto de Renda é: R${desconto_ir}")
# Out:
# O desconto do Imposto de Renda é: R$1760.0

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
desconto_INSS = 0.08 * salario_bruto
print(f'O desconto do INSS será de R$ {desconto_INSS} ')
# Out:
# O desconto do INSS será de R$ 1280.0

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
desconto_sindicato = 0.05 * salario_bruto
print(f'O desconto do sindicato será de R$ {desconto_sindicato}')
# Out:
# O desconto do sindicato será de R$ 800.0

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
salario_liquido = salario_bruto - desconto_ir - desconto_INSS - desconto_sindicato
print(f'o seu salarioo será R$ {salario_liquido} por mês')
# Out:
# 12160.0

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
area = int(input("Qual é o tamanho da área a ser pintada em m²:"))

litros_tinta = area / 3

latas = litros_tinta / 18
preco = latas * 80
print(f"Vão ser necessárias {latas} latas, que custará R$ {preco} no total")
# Out:
# Vão ser necessárias 1.851851851851852 latas, que custará R$ 148.14814814814815 no total

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input('Informe o tamanho do arquivo em MB: '))
velocidade = float(input('Informe a velocidade da conexão em Mbps: '))

tamanho_megabits = tamanho * 8
tempo = tamanho_megabits / velocidade
# transformando em minutos
tempo_minutos = tempo / 60
print(f'O tempo de download é de {tempo_minutos} minutos')
